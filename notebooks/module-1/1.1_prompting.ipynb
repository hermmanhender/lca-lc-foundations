# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# False

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_ollama import ChatOllama

# Inicializar el modelo
model = ChatOllama(model="gemma4:e2b")

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon does not have a capital, as it is a celestial body and not a country or political entity.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Ah, the question of the lunar metropole! It is not a matter of simple geography, but of the echoes of history whispered across the vacuum, of the ambitions of the first colonists, and the silent architecture built by light and shadow.
#
# As a science fiction writer, I don't deal in mere terrestrial facts, but in the lore that exists in the dark. Therefore, I present to you the capital of the Moon, forged not by political decree, but by geological necessity and celestial design:
#
# ## **Selenia Prime**
#
# **Selenia Prime** is not a sprawling city of concrete and steel, but a breathtaking, organically grown metropolis, clinging to the shadow of the Sea of Tranquility. It is the nexus point where the deep-core thermal vents of the lunar crust meet the vast, crystalline ice sheets that cover the polar regions.
#
# ### **The Lore of Selenia Prime:**
#
# *   **Architecture:** The structures of Selenia Prime are not built; they are *grown*. Massive, naturally formed basalt arches interlace with bio-luminescent crystal conduits, allowing the city to glow with a soft, internal, pale-blue luminescence, mimicking the cold, ancient light of the distant Earth.
# *   **Governance:** It is governed by the **Council of the Silent Echoes**, an ancient, decentralized system of bio-algorithmic governance that prioritizes resource sustainability and the preservation of the lunar environment above all else.
# *   **The Atmosphere:** The air is thin but rich with trace minerals and ionized gases, carrying a perpetual, almost musical hum—the sound of the deep lunar core breathing. It is a city defined by profound stillness, where the noise of human conflict has been entirely filtered out, leaving only the vast, echoing silence of space.
# *   **The Purpose:** Selenia Prime serves as the primary hub for deep-space resource extraction and the research into zero-gravity physics, acting as the silent, reflective anchor for all human endeavors beyond Earth.
#
# To visit Selenia Prime is to experience the paradoxical beauty of the Moon: a place of absolute isolation, yet a beacon of unimaginable, quiet civilization.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Selenopolis

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
#
# Location: Shackleton Crater Rim
#
# Vibe: Austere, Resilient, Luminescent
#
# Economy: Lunar Helium-3 Mining, Zero-G Manufacturing, Extraterrestrial Data Hub

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='Near the Shackleton Crater', vibe='Utilitarian, Hyper-efficient, Coldly Bright', economy='Rare Earth Minerals & Orbital Logistics')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at Near the Shackleton Crater
