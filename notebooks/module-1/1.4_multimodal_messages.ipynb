# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama

# Inicializar el modelo
model = ChatOllama(model="gemma4:e2b")

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The capital of the Moon is **Selene Prime**, often simply referred to by the inhabitants as *Luna Nova*.
#
# It is not a city built by mere construction, but a sprawling, biomechanical tapestry woven into the shadowed craters and illuminated by vast, crystalline solar arrays.
#
# ### Selene Prime: The City of Echoes
#
# **Location and Structure:**
# Selene Prime is situated within the vast, unmapped basin known as the Mare Imbrium, strategically chosen for its stable regolith composition and proximity to geothermal vents found deep beneath the lunar crust. The city is a layered marvel:
#
# 1. **The Zenith Spire:** The central administrative and energy hub, a kilometer-high lattice of ferro-silicate that pierces the lunar dust, constantly humming with harnessed solar energy. It is the beacon of the civilization, catching the sharp, unfiltered light of Earth in a breathtaking display.
# 2. **The Substrata:** Beneath the surface lies the true living space—a network of pressurized, bioluminescent caverns carved from the basaltic bedrock. Here reside the agricultural domes, the hydroponic parks, and the residential sectors, warmed by captured geothermal heat and lit by the soft, pulsing glow of bio-luminescent fungi.
# 3. **The Echo Tunnels:** Interconnecting the major districts are vast, silent transit tunnels, lined with ancient, crystalline conduits that hum with residual data streams—the city’s historical memory, flowing through light and vibration rather than spoken word.
#
# **Atmosphere and Culture:**
# Life in Selene Prime is defined by the stark, beautiful contrast of eternal night and blinding sunlight. The culture is intensely contemplative and focused on resource management, having evolved under the strict necessity of surviving in an environment utterly devoid of Earth's familiar atmosphere.
#
# The inhabitants, known as the Lunari, value silence, precision, and deep history. Their architecture reflects this: structures are organic yet rigidly geometric, seamlessly merging with the lunar landscape. They view the vacuum not as emptiness, but as the ultimate, perfect canvas for their civilization.
#
# **The Heart of the City:**
# The true heart of Selene Prime is not the Zenith Spire, but the **Aetherium Well**. This deep, artificially maintained cavern is where the Lunari draw their essential energy, communicating with the deep, cold silence of space, and where the collective consciousness of the city is maintained—a symphony of whispered data and ambient light that defines the civilization’s eternal existence.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ()

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 import base64
#       2
#       3 # Get the first (and only) uploaded file dict
# ----> 4 uploaded_file = uploader.value[0]
#       5
#       6 # This is a memoryview
#       7 content_mv = uploaded_file["content"]
#
# IndexError: tuple index out of range

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

# %%
agent = create_agent(
    model=model,
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
