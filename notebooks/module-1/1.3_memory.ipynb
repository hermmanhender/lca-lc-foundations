# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain_ollama import ChatOllama

# Inicializar el modelo
model = ChatOllama(model="gemma4:e2b")


agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='01dc77c5-0d92-485f-8434-96aaa8f25306'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a wonderful colour. 😊\n\nHow can I help you today?", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T13:49:29.2508842Z', 'done': True, 'done_reason': 'stop', 'total_duration': 26827774500, 'load_duration': 510699900, 'prompt_eval_count': 28, 'prompt_eval_duration': 930932900, 'eval_count': 243, 'eval_duration': 25103146700, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db573-8e4e-7ba2-93de-2bdcaeb8d8fb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 243, 'total_tokens': 271})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='b789c321-c8ee-46a4-bf13-f0b9179eb924'),
#               AIMessage(content="I do not have access to your personal information, so I don't know what your favorite color is.\n\nYou'll have to tell me! 😊", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T13:49:51.7293422Z', 'done': True, 'done_reason': 'stop', 'total_duration': 22430393100, 'load_duration': 556484900, 'prompt_eval_count': 23, 'prompt_eval_duration': 469214100, 'eval_count': 210, 'eval_duration': 21145149400, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db573-f74b-7ba3-89d6-8f06d2401855-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 210, 'total_tokens': 233})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='c50d9b72-d982-4c93-b930-da4ea693354d'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a wonderful colour! 😊", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T13:50:15.0301858Z', 'done': True, 'done_reason': 'stop', 'total_duration': 23167122000, 'load_duration': 650427500, 'prompt_eval_count': 28, 'prompt_eval_duration': 665106800, 'eval_count': 210, 'eval_duration': 21600800900, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db574-4f76-7bc0-83e3-20705a9967dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 210, 'total_tokens': 238})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='c50d9b72-d982-4c93-b930-da4ea693354d'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a wonderful colour! 😊", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T13:50:15.0301858Z', 'done': True, 'done_reason': 'stop', 'total_duration': 23167122000, 'load_duration': 650427500, 'prompt_eval_count': 28, 'prompt_eval_duration': 665106800, 'eval_count': 210, 'eval_duration': 21600800900, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db574-4f76-7bc0-83e3-20705a9967dc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 210, 'total_tokens': 238}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='93b9c47d-0643-4a77-81c5-70f2b2d12ea8'),
#               AIMessage(content='Your favourite colour is green! 😊', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T13:50:30.9692683Z', 'done': True, 'done_reason': 'stop', 'total_duration': 15775819200, 'load_duration': 493918600, 'prompt_eval_count': 64, 'prompt_eval_duration': 1302948100, 'eval_count': 133, 'eval_duration': 13802928600, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db574-aa97-74f1-80f4-bc912ba2f43e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 64, 'output_tokens': 133, 'total_tokens': 197})]}
