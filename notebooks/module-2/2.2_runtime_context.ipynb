# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class ColourContext:
    favourite_colour: str = "blue"
    least_favourite_colour: str = "yellow"

# %%
from langchain.agents import create_agent

from langchain_ollama import ChatOllama
model = ChatOllama(model="gemma4:e2b")

agent = create_agent(
    model=model,
    context_schema=ColourContext  
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='161cc961-6b15-4a8f-b262-f2ff7c94c595'),
#               AIMessage(content="I do not know what your favorite color is, as I don't have access to your personal information.\n\nIf you tell me, I'd be happy to hear it! 😊", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T15:27:06.8616251Z', 'done': True, 'done_reason': 'stop', 'total_duration': 35882404500, 'load_duration': 9879048600, 'prompt_eval_count': 22, 'prompt_eval_duration': 2374176900, 'eval_count': 240, 'eval_duration': 23004385000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db5cc-cc23-71b2-b016-40ad375e2534-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 240, 'total_tokens': 262})]}

# %% [markdown]
# ## Accessing Context

# %%
from langchain.tools import tool, ToolRuntime

@tool
def get_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the favourite colour of the user"""
    return runtime.context.favourite_colour

@tool
def get_least_favourite_colour(runtime: ToolRuntime) -> str:
    """Get the least favourite colour of the user"""
    return runtime.context.least_favourite_colour

# %%
agent = create_agent(
    model=model,
    tools=[get_favourite_colour, get_least_favourite_colour],
    context_schema=ColourContext
)

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext()
)

pprint(response)
# Out:
# C:\Users\grhen\Documents\GitHub2\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='9f18605b-5dcb-425a-b85c-59cf6a2f22f8'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T15:27:25.1564096Z', 'done': True, 'done_reason': 'stop', 'total_duration': 18126049100, 'load_duration': 560771900, 'prompt_eval_count': 87, 'prompt_eval_duration': 2303964400, 'eval_count': 162, 'eval_duration': 15111167000, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db5cd-5913-7ee1-9bb2-40052535c859-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': 'e5322ef3-ad5c-4aa9-9694-d7103f1ae2a1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 87, 'output_tokens': 162, 'total_tokens': 249}),
#               ToolMessage(content='blue', name='get_favourite_colour', id='c8235b08-dd54-4935-bf9b-23caf20e4c56', tool_call_id='e5322ef3-ad5c-4aa9-9694-d7103f1ae2a1'),
#               AIMessage(content="The user's favourite colour is blue.", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T15:27:27.2824339Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1910663700, 'load_duration': 474468600, 'prompt_eval_count': 110, 'prompt_eval_duration': 666758600, 'eval_count': 10, 'eval_duration': 759033600, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db5cd-a0c9-74a1-8d42-a89bea4a7c18-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 110, 'output_tokens': 10, 'total_tokens': 120})]}

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="What is my favourite colour?")]},
    context=ColourContext(favourite_colour="green")
)

pprint(response)
# Out:
# C:\Users\grhen\Documents\GitHub2\lca-lc-foundations\.venv\Lib\site-packages\pydantic\main.py:475: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `none` - serialized value may not be as expected [field_name='context', input_value=ColourContext(favourite_c...vourite_colour='yellow'), input_type=ColourContext])
#   return self.__pydantic_serializer__.to_python(
# {'messages': [HumanMessage(content='What is my favourite colour?', additional_kwargs={}, response_metadata={}, id='c92c6d2a-3fca-4997-a1ac-c5046e50abc0'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T15:27:43.2925684Z', 'done': True, 'done_reason': 'stop', 'total_duration': 15981908800, 'load_duration': 514469500, 'prompt_eval_count': 87, 'prompt_eval_duration': 82132900, 'eval_count': 169, 'eval_duration': 15264138200, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db5cd-a84c-7e41-9794-39ea5264c11a-0', tool_calls=[{'name': 'get_favourite_colour', 'args': {}, 'id': '21ea8731-7adf-4580-ac81-cc697feb7d64', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 87, 'output_tokens': 169, 'total_tokens': 256}),
#               ToolMessage(content='green', name='get_favourite_colour', id='22e68f90-cf00-4e0c-9ca2-77546acea68b', tool_call_id='21ea8731-7adf-4580-ac81-cc697feb7d64'),
#               AIMessage(content="The user's favourite colour is green.", additional_kwargs={}, response_metadata={'model': 'gemma4:e2b', 'created_at': '2026-04-22T15:27:45.4686802Z', 'done': True, 'done_reason': 'stop', 'total_duration': 2154130800, 'load_duration': 626596200, 'prompt_eval_count': 110, 'prompt_eval_duration': 665189900, 'eval_count': 10, 'eval_duration': 853982600, 'logprobs': None, 'model_name': 'gemma4:e2b', 'model_provider': 'ollama'}, id='lc_run--019db5cd-e6d1-7063-bfd2-c10f1f4bbf92-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 110, 'output_tokens': 10, 'total_tokens': 120})]}
